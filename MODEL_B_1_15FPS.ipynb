# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
# Parameters
FPS = 15  # Frames per second for extraction
ROOT_DIR = "/content/drive/MyDrive/research"
FRAME_DIR = os.path.join('extracted_frames_15fps')
DATA_DIR = os.path.join(ROOT_DIR, 'data')

# Create data generators
BATCH_SIZE = 1
MAX_FRAMES = 1000

# %%
import os
import cv2

def extract_frames(video_path, target_fps):
    video = cv2.VideoCapture(video_path)
    original_fps = int(video.get(cv2.CAP_PROP_FPS))
    frame_interval = original_fps // target_fps
    count = 0
    success, image = video.read()
    frames = []
    while success:
        if count % frame_interval == 0:
            frames.append(image)
        success, image = video.read()
        count += 1
    video.release()
    return frames

def save_frames(frames, folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    for i, frame in enumerate(frames):
        frame_path = os.path.join(folder_path, f"frame_{i}.jpg")
        cv2.imwrite(frame_path, frame)

def process_directory(directory_path, output_path, target_fps=FPS):
    for category in ['shoplifting videos', 'normal videos']:
        category_path = os.path.join(directory_path, category)
        video_files = [os.path.join(category_path, f) for f in os.listdir(category_path)]

        for video_file in video_files:
            frames = extract_frames(video_file, target_fps)
            video_base_name = os.path.splitext(os.path.basename(video_file))[0]
            frame_folder = os.path.join(output_path, category, video_base_name)
            save_frames(frames, frame_folder)

if not os.path.exists(FRAME_DIR):
    for subset in ['train', 'test', 'validation']:
        process_directory(os.path.join(DATA_DIR, subset), os.path.join(FRAME_DIR, subset), target_fps=FPS)

# %%
import tensorflow as tf
import tensorflow_hub as hub
import os
import cv2
import numpy as np
from tensorflow.keras.utils import Sequence

# Load the pre-trained ResNet50 model for feature extraction
resnet50_url = "https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4"
feature_extractor = hub.KerasLayer(resnet50_url, trainable=False)

def extract_features(image, frame_size=(224, 224)):
    """Extract features from image using ResNet50."""
    image = tf.image.resize(image, frame_size)
    image = tf.expand_dims(image, axis=0)
    features = feature_extractor(image)
    return features.numpy().flatten()

class PyDataset(Sequence):
    def __init__(self, data_dir, batch_size=8, frame_size=(224, 224), max_frames=30, **kwargs):
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.frame_size = frame_size
        self.max_frames = max_frames
        self.classes = ['normal videos', 'shoplifting videos']
        self.file_paths = []
        for class_idx, class_name in enumerate(self.classes):
            class_dir = os.path.join(data_dir, class_name)
            videos = [os.path.join(class_dir, video) for video in os.listdir(class_dir)]
            for video in videos:
                frames = [os.path.join(video, fname) for fname in os.listdir(video) if fname.endswith('.jpg')]
                self.file_paths.append((frames, class_idx))
        self.on_epoch_end()
        super().__init__(**kwargs)

    def __len__(self):
        return (len(self.file_paths) + self.batch_size - 1) // self.batch_size  # Ensure rounding up

    def __getitem__(self, idx):
        batch_paths = self.file_paths[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_frames = []
        batch_labels = []
        for paths, label in batch_paths:
            frames = []
            total_frames = len(paths)
            frame_interval = max(1, total_frames // self.max_frames)  # Downsample based on max_frames
            for i in range(0, total_frames, frame_interval):
                if len(frames) >= self.max_frames:
                    break
                frame = cv2.imread(paths[i])
                frame = cv2.resize(frame, self.frame_size)
                frame = tf.convert_to_tensor(frame, dtype=tf.float32) / 255.0  # Normalize to [0, 1]
                features = extract_features(frame, self.frame_size)
                frames.append(features)
            if len(frames) < self.max_frames:
                frames.extend([np.zeros(2048)] * (self.max_frames - len(frames)))  # Padding with zeros
            batch_frames.append(frames)
            batch_labels.append(label)

        batch_frames = np.array(batch_frames)
        batch_labels = np.array(batch_labels)

        return batch_frames, batch_labels

    def on_epoch_end(self):
        np.random.shuffle(self.file_paths)


train_gen = PyDataset(os.path.join(FRAME_DIR, 'train'), batch_size=BATCH_SIZE, max_frames=MAX_FRAMES)
val_gen = PyDataset(os.path.join(FRAME_DIR, 'validation'), batch_size=BATCH_SIZE, max_frames=MAX_FRAMES)
test_gen = PyDataset(os.path.join(FRAME_DIR, 'test'), batch_size=BATCH_SIZE, max_frames=MAX_FRAMES)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, TimeDistributed, Masking
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall, AUC

def create_rnn_model(input_shape):
    inputs = Input(shape=input_shape)
    masked = Masking(mask_value=0.)(inputs)  # Mask padding
    time_distributed = TimeDistributed(Dense(128, activation='relu'))(masked)
    lstm = LSTM(512, return_sequences=False)(time_distributed)
    outputs = Dense(1, activation='sigmoid')(lstm)
    model = Model(inputs, outputs)
    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy', Precision(), Recall(), AUC()])
    return model

# Create and train the RNN model
input_shape = (MAX_FRAMES, 2048)  # MAX_FRAMES for sequence length, 2048 for feature vector size from ResNet50
rnn_model = create_rnn_model(input_shape)
rnn_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1000, 2048)]      0
#
#  masking (Masking)           (None, 1000, 2048)        0
#
#  time_distributed (TimeDistr  (None, 1000, 128)        262272
#  ibuted)
#
#  lstm (LSTM)                 (None, 512)               1312768
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1,575,553
# Trainable params: 1,575,553
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_cb = ModelCheckpoint(os.path.join(ROOT_DIR, 'models', 'model_b_1_15fps.keras' ), save_best_only=True)

# history = rnn_model.fit(train_gen, epochs=20, validation_data=val_gen, callbacks=[checkpoint_cb])


# Specify that you want to use the GPU
if tf.config.list_physical_devices('GPU'):
    with tf.device('GPU:0'):
        history = rnn_model.fit(train_gen, epochs=20, validation_data=val_gen, callbacks=[checkpoint_cb])
else:
    print("No GPU available, using CPU.")
# Out:
# Epoch 1/20
# 84/84 [==============================] - 2091s 24s/step - loss: 0.8179 - accuracy: 0.6667 - precision: 0.6591 - recall: 0.6905 - auc: 0.6392 - val_loss: 0.5485 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.8395
# Epoch 2/20
# 84/84 [==============================] - 1558s 19s/step - loss: 0.2680 - accuracy: 0.8810 - precision: 0.8810 - recall: 0.8810 - auc: 0.9563 - val_loss: 1.0272 - val_accuracy: 0.5556 - val_precision: 0.6667 - val_recall: 0.2222 - val_auc: 0.7840
# Epoch 3/20
# 84/84 [==============================] - 1548s 19s/step - loss: 0.0611 - accuracy: 0.9762 - precision: 0.9762 - recall: 0.9762 - auc: 0.9991 - val_loss: 0.9174 - val_accuracy: 0.7222 - val_precision: 0.7000 - val_recall: 0.7778 - val_auc: 0.8210
# Epoch 4/20
# 84/84 [==============================] - 1551s 18s/step - loss: 0.0024 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.5511 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7654
# Epoch 5/20
# 84/84 [==============================] - 1556s 18s/step - loss: 5.8760e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.6631 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7716
# Epoch 6/20
# 84/84 [==============================] - 1548s 18s/step - loss: 3.3431e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.7840 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7346
# Epoch 7/20
# 84/84 [==============================] - 1487s 18s/step - loss: 2.2211e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.8764 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7346
# Epoch 8/20
# 84/84 [==============================] - 1478s 18s/step - loss: 1.5565e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 1.9517 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7346
# Epoch 9/20
# 84/84 [==============================] - 1476s 18s/step - loss: 1.1553e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.0105 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 10/20
# 84/84 [==============================] - 1476s 18s/step - loss: 8.9185e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.0684 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 11/20
# 84/84 [==============================] - 1489s 18s/step - loss: 7.0799e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.1111 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 12/20
# 84/84 [==============================] - 1478s 18s/step - loss: 5.7716e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.1550 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 13/20
# 84/84 [==============================] - 1526s 18s/step - loss: 4.7717e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.1948 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 14/20
# 84/84 [==============================] - 1839s 22s/step - loss: 3.9955e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.2272 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 15/20
# 84/84 [==============================] - 2642s 31s/step - loss: 3.3819e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.2590 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 16/20
# 84/84 [==============================] - 1640s 20s/step - loss: 2.9155e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.2820 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 17/20
# 84/84 [==============================] - 1750s 21s/step - loss: 2.5380e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.3057 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 18/20
# 84/84 [==============================] - 1669s 20s/step - loss: 2.2293e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.3312 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 19/20
# 84/84 [==============================] - 1962s 23s/step - loss: 1.9788e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.3490 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407
# Epoch 20/20
# 84/84 [==============================] - 1804s 22s/step - loss: 1.7685e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 2.3702 - val_accuracy: 0.7778 - val_precision: 0.8571 - val_recall: 0.6667 - val_auc: 0.7407

# %%
import pickle

# Save the history
with open(os.path.join(ROOT_DIR,'models','model_b_1_15FPS.pkl'), 'wb') as file:
    pickle.dump(history.history, file)

# Load the history
with open(os.path.join(ROOT_DIR,'models','model_b_1_15FPS.pkl'), 'rb') as file:
    history = pickle.load(file)

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Load the best model and evaluate it
rnn_model.load_weights(os.path.join(ROOT_DIR, 'models', 'model_b_1_15fps.keras'))
loss, accuracy, precision, recall, auc_score = rnn_model.evaluate(test_gen)
print(f'Test Accuracy: {accuracy}')
print(f'Test Precision: {precision}')
print(f'Test Recall: {recall}')
print(f'Test AUC: {auc_score}')
# Out:
# 18/18 [==============================] - 297s 16s/step - loss: 0.4025 - accuracy: 0.7778 - precision: 0.8571 - recall: 0.6667 - auc: 0.9198
# Test Accuracy: 0.7777777910232544
# Test Precision: 0.8571428656578064
# Test Recall: 0.6666666865348816
# Test AUC: 0.9197530746459961

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize lists for predictions and true labels
y_pred = []
y_true = []

# Get the number of steps in the generator
num_steps = len(test_gen)

# Iterate over the test generator batches
for i, (batch_frames, batch_labels) in enumerate(test_gen):
    if i >= num_steps:
        break
    try:
        print(f"Processing batch {i+1}/{num_steps}")
        predictions = rnn_model.predict(batch_frames)  # Disable progress bar
        # Ensure predictions are in the range [0, 1]
        predictions = np.clip(predictions, 0, 1)
        # Round predictions to get binary outputs (0 or 1)
        rounded_predictions = np.round(predictions).astype(int).flatten()

        # Debugging Statements
        print("Batch Frames Shape:", batch_frames.shape)
        print("Batch Labels Shape:", batch_labels.shape)
        print("Predictions Shape:", predictions.shape)
        print("Rounded Predictions:", rounded_predictions)
        print("True Labels:", batch_labels.flatten())
        print("Min Prediction:", np.min(predictions), "Max Prediction:", np.max(predictions))
        print("Min Label:", np.min(batch_labels), "Max Label:", np.max(batch_labels))
        print("Predictions Contain NaN:", np.any(np.isnan(predictions)))
        print("Labels Contain NaN:", np.any(np.isnan(batch_labels)))

        y_pred.extend(rounded_predictions)
        y_true.extend(batch_labels.flatten())
    except Exception as e:
        print(f"Error processing batch {i+1}: {e}")
        break

# Generate classification report and confusion matrix
try:
    print("Unique predictions:", np.unique(y_pred))
    print("Unique true labels:", np.unique(y_true))
    print("Classification Report:")
    print(classification_report(y_true, y_pred, target_names=['Class 0', 'Class 1']))
except Exception as e:
    print(f"Error in classification_report: {e}")

try:
    print("Confusion Matrix:")
    cm = confusion_matrix(y_true, y_pred)
    print(cm)
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
except Exception as e:
    print(f"Error in confusion_matrix plotting: {e}")
# Out:
# Processing batch 1/18
# 1/1 [==============================] - 3s 3s/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [0]
# Min Prediction: 0.13060515 Max Prediction: 0.13060515
# Min Label: 0 Max Label: 0
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 2/18
# 1/1 [==============================] - 0s 65ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [1]
# True Labels: [1]
# Min Prediction: 0.8946981 Max Prediction: 0.8946981
# Min Label: 1 Max Label: 1
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 3/18
# 1/1 [==============================] - 0s 47ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [1]
# Min Prediction: 0.33887184 Max Prediction: 0.33887184
# Min Label: 1 Max Label: 1
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 4/18
# 1/1 [==============================] - 0s 52ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [1]
# True Labels: [1]
# Min Prediction: 0.74770695 Max Prediction: 0.74770695
# Min Label: 1 Max Label: 1
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 5/18
# 1/1 [==============================] - 0s 69ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [1]
# True Labels: [1]
# Min Prediction: 0.8978973 Max Prediction: 0.8978973
# Min Label: 1 Max Label: 1
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 6/18
# 1/1 [==============================] - 0s 78ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [0]
# Min Prediction: 0.10789383 Max Prediction: 0.10789383
# Min Label: 0 Max Label: 0
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 7/18
# 1/1 [==============================] - 0s 69ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [1]
# True Labels: [1]
# Min Prediction: 0.67823786 Max Prediction: 0.67823786
# Min Label: 1 Max Label: 1
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 8/18
# 1/1 [==============================] - 0s 53ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [0]
# Min Prediction: 0.19788103 Max Prediction: 0.19788103
# Min Label: 0 Max Label: 0
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 9/18
# 1/1 [==============================] - 0s 62ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [0]
# Min Prediction: 0.112529986 Max Prediction: 0.112529986
# Min Label: 0 Max Label: 0
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 10/18
# 1/1 [==============================] - 0s 44ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [0]
# Min Prediction: 0.059103355 Max Prediction: 0.059103355
# Min Label: 0 Max Label: 0
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 11/18
# 1/1 [==============================] - 0s 70ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [0]
# Min Prediction: 0.44048136 Max Prediction: 0.44048136
# Min Label: 0 Max Label: 0
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 12/18
# 1/1 [==============================] - 0s 102ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [1]
# True Labels: [0]
# Min Prediction: 0.7445356 Max Prediction: 0.7445356
# Min Label: 0 Max Label: 0
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 13/18
# 1/1 [==============================] - 0s 53ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [1]
# True Labels: [1]
# Min Prediction: 0.5748568 Max Prediction: 0.5748568
# Min Label: 1 Max Label: 1
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 14/18
# 1/1 [==============================] - 0s 68ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [1]
# True Labels: [1]
# Min Prediction: 0.8793246 Max Prediction: 0.8793246
# Min Label: 1 Max Label: 1
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 15/18
# 1/1 [==============================] - 0s 118ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [0]
# Min Prediction: 0.32615823 Max Prediction: 0.32615823
# Min Label: 0 Max Label: 0
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 16/18
# 1/1 [==============================] - 0s 73ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [0]
# Min Prediction: 0.12721978 Max Prediction: 0.12721978
# Min Label: 0 Max Label: 0
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 17/18
# 1/1 [==============================] - 0s 63ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [1]
# Min Prediction: 0.49141273 Max Prediction: 0.49141273
# Min Label: 1 Max Label: 1
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Processing batch 18/18
# 1/1 [==============================] - 0s 51ms/step
# Batch Frames Shape: (1, 1000, 2048)
# Batch Labels Shape: (1,)
# Predictions Shape: (1, 1)
# Rounded Predictions: [0]
# True Labels: [1]
# Min Prediction: 0.4767059 Max Prediction: 0.4767059
# Min Label: 1 Max Label: 1
# Predictions Contain NaN: False
# Labels Contain NaN: False
# Unique predictions: [0 1]
# Unique true labels: [0 1]
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.73      0.89      0.80         9
#      Class 1       0.86      0.67      0.75         9
#
#     accuracy                           0.78        18
#    macro avg       0.79      0.78      0.78        18
# weighted avg       0.79      0.78      0.77        18
#
# Confusion Matrix:
# [[8 1]
#  [3 6]]

# %%
from sklearn.metrics import roc_curve, auc

# ROC Curve
fpr, tpr, _ = roc_curve(y_true, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub

def extract_features(frame, frame_size=(224, 224)):
    resnet_model = hub.KerasLayer("https://tfhub.dev/tensorflow/resnet_50/feature_vector/1", trainable=False)
    preprocess_input = tf.keras.applications.resnet50.preprocess_input
    frame = preprocess_input(frame)
    frame = tf.image.resize(frame, frame_size)
    frame = tf.expand_dims(frame, axis=0)  # Add batch dimension
    features = resnet_model(frame)
    return features.numpy().flatten()

def load_and_preprocess_video(video_path, frame_size=(224, 224), max_frames=30, target_fps=5):
    cap = cv2.VideoCapture(video_path)
    frame_rate = cap.get(cv2.CAP_PROP_FPS)
    frame_interval = int(frame_rate // target_fps)
    frames = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if len(frames) % frame_interval == 0:
            frame = cv2.resize(frame, frame_size)
            frame = tf.convert_to_tensor(frame, dtype=tf.float32) / 255.0  # Normalize to [0, 1]
            features = extract_features(frame)
            frames.append(features)
        if len(frames) >= max_frames:
            break

    cap.release()

    # Ensure all frames have the same shape by padding with zeros
    feature_dim = 2048  # ResNet50 feature vector size
    if len(frames) < max_frames:
        padding = [np.zeros(feature_dim)] * (max_frames - len(frames))
        frames.extend(padding)
    elif len(frames) > max_frames:
        frames = frames[:max_frames]

    return np.array(frames)

video_paths = os.listdir(os.path.join(DATA_DIR, 'test', 'normal videos'))

for video in video_paths:
    full_video_path = os.path.join(DATA_DIR, 'test', 'normal videos', video)
    video_frames = load_and_preprocess_video(full_video_path)
    video_frames = np.expand_dims(video_frames, axis=0)  # Add batch dimension

    try:
        predictions = rnn_model.predict(video_frames)
        predictions = np.clip(predictions, 0, 1)
        rounded_predictions = np.round(predictions).astype(int).flatten()

        if rounded_predictions.mean() > 0.5:
            print("The video is classified as a shoplifting video.")
        else:
            print("The video is classified as a normal video.")
    except Exception as e:
        print(f"Error processing video {video}: {e}")

# %%
def load_and_preprocess_video(video_path, frame_size=(224, 224), max_frames=30, target_fps=5):
    cap = cv2.VideoCapture(video_path)
    frame_rate = cap.get(cv2.CAP_PROP_FPS)
    frame_interval = int(frame_rate // target_fps)
    frames = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if len(frames) % frame_interval == 0:
            frame = cv2.resize(frame, frame_size)
            frame = tf.convert_to_tensor(frame, dtype=tf.float32) / 255.0  # Normalize to [0, 1]
            features = extract_features(frame, frame_size)
            frames.append(features)
        if len(frames) >= max_frames:
            break

    cap.release()
    if len(frames) < max_frames:
        frames.extend([np.zeros(2048)] * (max_frames - len(frames)))  # Padding with zeros

    return np.array(frames)

# %%
video_paths = os.listdir(os.path.join(DATA_DIR,'test', 'normal videos'))

for video in video_paths:
    full_video_path = os.path.join(DATA_DIR, 'test', 'normal videos', video)
    video_frames = load_and_preprocess_video(full_video_path, max_frames=MAX_FRAMES)
    video_frames = np.expand_dims(video_frames, axis=0)  # Add batch dimension

    # Make predictions on the video frames
    predictions = rnn_model.predict(video_frames)

    # Ensure predictions are in the range [0, 1]
    predictions = np.clip(predictions, 0, 1)
    # Round predictions to get binary outputs (0 or 1)
    rounded_predictions = np.round(predictions).astype(int).flatten()

    # binary classification: 0 = normal video, 1 = shoplifting video
    if rounded_predictions.mean() > 0.5:
        print("The video is classified as a shoplifting video.")
    else:
        print("The video is classified as a normal video.")
# Out:
# 1/1 [==============================] - 2s 2s/step
# The video is classified as a normal video.
# 1/1 [==============================] - 0s 33ms/step
# The video is classified as a normal video.
# 1/1 [==============================] - 0s 51ms/step
# The video is classified as a normal video.
# 1/1 [==============================] - 0s 45ms/step
# The video is classified as a normal video.
# 1/1 [==============================] - 0s 33ms/step
# The video is classified as a shoplifting video.
# 1/1 [==============================] - 0s 47ms/step
# The video is classified as a normal video.
# 1/1 [==============================] - 0s 33ms/step
# The video is classified as a normal video.
# 1/1 [==============================] - 0s 32ms/step
# The video is classified as a shoplifting video.
# 1/1 [==============================] - 0s 32ms/step
# The video is classified as a normal video.

# %%
video_paths = os.listdir(os.path.join(DATA_DIR, 'test', 'shoplifting videos'))
for video in video_paths:
    full_video_path = os.path.join(DATA_DIR, 'test', 'shoplifting videos', video)
    video_frames = load_and_preprocess_video(full_video_path, max_frames=MAX_FRAMES)
    video_frames = np.expand_dims(video_frames, axis=0)  # Add batch dimension

    # Make predictions on the video frames
    predictions = rnn_model.predict(video_frames)

    # Ensure predictions are in the range [0, 1]
    predictions = np.clip(predictions, 0, 1)
    # Round predictions to get binary outputs (0 or 1)
    rounded_predictions = np.round(predictions).astype(int).flatten()

    # binary classification: 0 = normal video, 1 = shoplifting video
    if rounded_predictions.mean() > 0.5:
        print("The video is classified as a shoplifting video.")
    else:
        print("The video is classified as a normal video.")
# Out:
# 1/1 [==============================] - 0s 48ms/step
# The video is classified as a shoplifting video.
# 1/1 [==============================] - 0s 47ms/step
# The video is classified as a shoplifting video.
# 1/1 [==============================] - 0s 46ms/step
# The video is classified as a shoplifting video.
# 1/1 [==============================] - 0s 60ms/step
# The video is classified as a normal video.
# 1/1 [==============================] - 0s 53ms/step
# The video is classified as a shoplifting video.
# 1/1 [==============================] - 0s 59ms/step
# The video is classified as a shoplifting video.
# 1/1 [==============================] - 0s 39ms/step
# The video is classified as a shoplifting video.
# 1/1 [==============================] - 0s 37ms/step
# The video is classified as a shoplifting video.
# 1/1 [==============================] - 0s 50ms/step
# The video is classified as a shoplifting video.
